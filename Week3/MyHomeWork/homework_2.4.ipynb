# %% [markdown]
# # 使用朴素贝叶斯分类器从个人广告中获取区域倾向

# %% [markdown]
# 1. 收集数据：从RSS源收集内容，这里需要对RSS源构建一个接口。
# 2. 准备数据：将文本文件解析成词条向量。
# 3. 分析数据：检查词条确保解析的正确性。
# 4. 训练算法：使用trainNB0()函数。
# 5. 测试算法：观察错误率，确保分类器可用。可以修改切分程序，以降低错误率，提高分类结果。
# 6. 使用算法：构建一个完整的程序，封装所有内容。给定两个RSS源，该程序会显示最常用的公共词。

# %% [markdown]
# ## 收集数据：导入RSS源

# %%
import feedparser
import jieba
import random
import numpy as np
from math import log
import re

# %%
ny = feedparser.parse('http://www.caijing.com.cn/rss/stock_index.xml')

# %%
ny['entries']
# Out:
# [{'title': '昊志机电：控制人突击注销企业 治理结构堪忧',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '昊志机电：控制人突击注销企业 治理结构堪忧'},
#   'summary': '此前，我们曾经从公司毛利率下滑、应收账款积累、产能利用率不足等角度分析了昊志机电存在的几大方面问题。这次，我们将继续深入解析该公司存在的几项风险因素，其一是公司实际控制人及其近亲属在申请上市前夕突...<br><a href="http://stock.caijing.com.cn/2014-08-25/114339054.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '此前，我们曾经从公司毛利率下滑、应收账款积累、产能利用率不足等角度分析了昊志机电存在的几大方面问题。这次，我们将继续深入解析该公司存在的几项风险因素，其一是公司实际控制人及其近亲属在申请上市前夕突...<br><a href="http://stock.caijing.com.cn/2014-08-25/114339054.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-25/114339054.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-25/114339054.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': "<a href='' target='_blank'>文/IPO研究中心</a>"}],
#   'author': "<a href='' target='_blank'>文/IPO研究中心</a>",
#   'author_detail': {'name': "<a href='' target='_blank'>文/IPO研究中心</a>"},
#   'published': 'Mon, 25 Aug 2014 09:50:52 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=25, tm_hour=1, tm_min=50, tm_sec=52, tm_wday=0, tm_yday=237, tm_isdst=0)},
#  {'title': '中国手游集团获少林寺授权开发少林题材手游',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中国手游集团获少林寺授权开发少林题材手游'},
#   'summary': '中证网讯 8月2日，纳斯达克上市公司、领先的移动游戏开发商与发行商中国手游集团(NASDAQ:CMGE)与中国嵩山少林寺全资公司河南少林无形资产管理有限公司正式签订合作协议，授权中国手游集团使用少...<br><a href="http://stock.caijing.com.cn/2014-08-02/114334726.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 8月2日，纳斯达克上市公司、领先的移动游戏开发商与发行商中国手游集团(NASDAQ:CMGE)与中国嵩山少林寺全资公司河南少林无形资产管理有限公司正式签订合作协议，授权中国手游集团使用少...<br><a href="http://stock.caijing.com.cn/2014-08-02/114334726.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-02/114334726.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-02/114334726.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '本报记者 万晶'}],
#   'author': '本报记者 万晶',
#   'author_detail': {'name': '本报记者 万晶'},
#   'published': 'Sat, 02 Aug 2014 19:08:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=2, tm_hour=11, tm_min=8, tm_sec=0, tm_wday=5, tm_yday=214, tm_isdst=0)},
#  {'title': '中国手游与全球顶级版权方开展战略合作 发布多款手游新品',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中国手游与全球顶级版权方开展战略合作 发布多款手游新品'},
#   'summary': '中证网讯 8月2日，在中国国际数码互动娱乐展览会（简称China Joy）期间，纳斯达克上市公司、领先的移动游戏开发商与发行商中国手游集团(NASDAQ:CMGE)正式公布了其精品与品牌战略成果，...<br><a href="http://stock.caijing.com.cn/2014-08-02/114334727.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 8月2日，在中国国际数码互动娱乐展览会（简称China Joy）期间，纳斯达克上市公司、领先的移动游戏开发商与发行商中国手游集团(NASDAQ:CMGE)正式公布了其精品与品牌战略成果，...<br><a href="http://stock.caijing.com.cn/2014-08-02/114334727.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-02/114334727.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-02/114334727.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '本报记者 万晶'}],
#   'author': '本报记者 万晶',
#   'author_detail': {'name': '本报记者 万晶'},
#   'published': 'Sat, 02 Aug 2014 19:05:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=2, tm_hour=11, tm_min=5, tm_sec=0, tm_wday=5, tm_yday=214, tm_isdst=0)},
#  {'title': '中小板一周活跃个股排行榜',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中小板一周活跃个股排行榜'},
#   'summary': '成交金额前十名的股票: (2014.07.28 - 2014.08.01)次序 股票代码 股票名称\u3000\u3000\u3000\u3000 成交金额\u3000 占板块(%) 1&n<br><a href="http://stock.caijing.com.cn/2014-08-02/114334449.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '成交金额前十名的股票: (2014.07.28 - 2014.08.01)次序 股票代码 股票名称\u3000\u3000\u3000\u3000 成交金额\u3000 占板块(%) 1&n<br><a href="http://stock.caijing.com.cn/2014-08-02/114334449.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-02/114334449.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-02/114334449.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Sat, 02 Aug 2014 10:16:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=2, tm_hour=2, tm_min=16, tm_sec=0, tm_wday=5, tm_yday=214, tm_isdst=0)},
#  {'title': '中小板周行情涨跌幅排行榜',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中小板周行情涨跌幅排行榜'},
#   'summary': '十只周涨幅最大的股票: (2014.07.28 - 2014.08.01)次序 股票代码 股票名称\u3000\u3000\u3000\u3000 收盘价\u3000涨幅 1 002728 台城制药&n<br><a href="http://stock.caijing.com.cn/2014-08-02/114334450.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '十只周涨幅最大的股票: (2014.07.28 - 2014.08.01)次序 股票代码 股票名称\u3000\u3000\u3000\u3000 收盘价\u3000涨幅 1 002728 台城制药&n<br><a href="http://stock.caijing.com.cn/2014-08-02/114334450.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-02/114334450.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-02/114334450.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Sat, 02 Aug 2014 10:15:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=2, tm_hour=2, tm_min=15, tm_sec=0, tm_wday=5, tm_yday=214, tm_isdst=0)},
#  {'title': '创业板一周活跃个股排行榜',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '创业板一周活跃个股排行榜'},
#   'summary': '成交金额前十名的股票: (2014.07.28 - 2014.08.01)次序 股票代码 股票名称\u3000\u3000\u3000\u3000 成交金额\u3000 占板块(%) 1&n<br><a href="http://stock.caijing.com.cn/2014-08-02/114334451.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '成交金额前十名的股票: (2014.07.28 - 2014.08.01)次序 股票代码 股票名称\u3000\u3000\u3000\u3000 成交金额\u3000 占板块(%) 1&n<br><a href="http://stock.caijing.com.cn/2014-08-02/114334451.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-02/114334451.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-02/114334451.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Sat, 02 Aug 2014 10:15:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=2, tm_hour=2, tm_min=15, tm_sec=0, tm_wday=5, tm_yday=214, tm_isdst=0)},
#  {'title': '创业板周行情涨跌幅排行榜',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '创业板周行情涨跌幅排行榜'},
#   'summary': '十只周涨幅最大的股票: (2014.07.28 - 2014.08.01)次序 股票代码 股票名称\u3000\u3000\u3000\u3000 收盘价\u3000涨幅 1 300390 天华超净&n<br><a href="http://stock.caijing.com.cn/2014-08-02/114334452.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '十只周涨幅最大的股票: (2014.07.28 - 2014.08.01)次序 股票代码 股票名称\u3000\u3000\u3000\u3000 收盘价\u3000涨幅 1 300390 天华超净&n<br><a href="http://stock.caijing.com.cn/2014-08-02/114334452.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-02/114334452.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-02/114334452.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Sat, 02 Aug 2014 10:02:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=2, tm_hour=2, tm_min=2, tm_sec=0, tm_wday=5, tm_yday=214, tm_isdst=0)},
#  {'title': '标普指数遭遇两年多来最大周跌幅',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '标普指数遭遇两年多来最大周跌幅'},
#   'summary': '中证网讯 由于投资者情绪仍显消极，纽约股市１日继续下跌。受前一天大跌拖累，三大股指本周均告跌，其中标普指数录得两年多来最大周跌幅。\u3000\u3000截至当天收盘，道琼斯工业平均指数比前一个交易日下跌６９．９３点...<br><a href="http://stock.caijing.com.cn/2014-08-02/114334267.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 由于投资者情绪仍显消极，纽约股市１日继续下跌。受前一天大跌拖累，三大股指本周均告跌，其中标普指数录得两年多来最大周跌幅。\u3000\u3000截至当天收盘，道琼斯工业平均指数比前一个交易日下跌６９．９３点...<br><a href="http://stock.caijing.com.cn/2014-08-02/114334267.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-02/114334267.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-02/114334267.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '刘凡'}],
#   'author': '刘凡',
#   'author_detail': {'name': '刘凡'},
#   'published': 'Sat, 02 Aug 2014 08:01:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=2, tm_hour=0, tm_min=1, tm_sec=0, tm_wday=5, tm_yday=214, tm_isdst=0)},
#  {'title': '纽约油价１日下跌0.30%',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '纽约油价１日下跌0.30%'},
#   'summary': '中证网讯 美国国内原油供应充裕，加上乌克兰和中东的紧张局势未对原油供应产生影响，国际油价１日继续下跌。\u3000\u3000至当日收盘时，纽约商品交易所２０１４年９月交货的轻质原油期货价格下跌０．２９美元，收于每桶...<br><a href="http://stock.caijing.com.cn/2014-08-02/114334268.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 美国国内原油供应充裕，加上乌克兰和中东的紧张局势未对原油供应产生影响，国际油价１日继续下跌。\u3000\u3000至当日收盘时，纽约商品交易所２０１４年９月交货的轻质原油期货价格下跌０．２９美元，收于每桶...<br><a href="http://stock.caijing.com.cn/2014-08-02/114334268.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-02/114334268.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-02/114334268.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '黄继汇'}],
#   'author': '黄继汇',
#   'author_detail': {'name': '黄继汇'},
#   'published': 'Sat, 02 Aug 2014 07:59:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=23, tm_min=59, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '利空经济数据打压欧股',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '利空经济数据打压欧股'},
#   'summary': '受利空的英国和欧元区制造业数据打压，欧洲股市１日承压明显，主要股指在早盘阶段跌幅一路扩大。午盘阶段，美国公布利好的制造业数据，股指止跌并小幅反弹，但由于同时公布的劳动力市场数据差于预期，使得股指最...<br><a href="http://stock.caijing.com.cn/2014-08-02/114334269.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '受利空的英国和欧元区制造业数据打压，欧洲股市１日承压明显，主要股指在早盘阶段跌幅一路扩大。午盘阶段，美国公布利好的制造业数据，股指止跌并小幅反弹，但由于同时公布的劳动力市场数据差于预期，使得股指最...<br><a href="http://stock.caijing.com.cn/2014-08-02/114334269.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-02/114334269.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-02/114334269.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '吴心韬'}],
#   'author': '吴心韬',
#   'author_detail': {'name': '吴心韬'},
#   'published': 'Sat, 02 Aug 2014 07:58:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=23, tm_min=58, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '美股开盘波动不大 欧股继续走软',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '美股开盘波动不大 欧股继续走软'},
#   'summary': '美国劳工部8月1日公布的最新数据显示,7月非农就业人数增加20.9万,虽然逊于预期的23万,但实现了1997年以来首次连续6个月增幅在20万以上。6月非农就业人数由此前的28.8万上修至29.8万...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334249.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '美国劳工部8月1日公布的最新数据显示,7月非农就业人数增加20.9万,虽然逊于预期的23万,但实现了1997年以来首次连续6个月增幅在20万以上。6月非农就业人数由此前的28.8万上修至29.8万...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334249.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334249.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334249.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '张枕河'}],
#   'author': '张枕河',
#   'author_detail': {'name': '张枕河'},
#   'published': 'Fri, 01 Aug 2014 22:29:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=14, tm_min=29, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '川仪股份8月5日在上交所上市交易',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '川仪股份8月5日在上交所上市交易'},
#   'summary': '中证网讯 据上交所消息，重庆川仪自动化股份有限公司10,000万股A股股票将于2014年8月5日在上交所市场上市交易，证券简称为"川仪股份"，证券代码为"603100"。\u3000\u3000该公司A股股本为39,...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334245.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 据上交所消息，重庆川仪自动化股份有限公司10,000万股A股股票将于2014年8月5日在上交所市场上市交易，证券简称为"川仪股份"，证券代码为"603100"。\u3000\u3000该公司A股股本为39,...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334245.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334245.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334245.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '周松林'}],
#   'author': '周松林',
#   'author_detail': {'name': '周松林'},
#   'published': 'Fri, 01 Aug 2014 21:50:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=13, tm_min=50, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '中证解读：中国高科借道东亚信托布局新生意',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证解读：中国高科借道东亚信托布局新生意'},
#   'summary': '中证网讯中国高科（600730）8月1日晚间公告称，自公司股票停牌以来，公司积极筹划非公开发行股票，拟向公司控股股东方正集团购<br><a href="http://stock.caijing.com.cn/2014-08-01/114334246.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯中国高科（600730）8月1日晚间公告称，自公司股票停牌以来，公司积极筹划非公开发行股票，拟向公司控股股东方正集团购<br><a href="http://stock.caijing.com.cn/2014-08-01/114334246.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334246.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334246.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '戴小河'}],
#   'author': '戴小河',
#   'author_detail': {'name': '戴小河'},
#   'published': 'Fri, 01 Aug 2014 21:38:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=13, tm_min=38, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '中证解读：*ST贤成重组对象曝光 “未婚妻”绯闻缠身',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证解读：*ST贤成重组对象曝光 “未婚妻”绯闻缠身'},
#   'summary': '中证网讯 徘徊于退市边缘的*ST贤成 （600381），终于在8月1日晚间抖出一纸公告，公司重大资产重组拟出售公司的经营性资产，同时发行股份购买青海春天药用资源科技利用有限公司（下称青海春天）的股...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334241.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 徘徊于退市边缘的*ST贤成 （600381），终于在8月1日晚间抖出一纸公告，公司重大资产重组拟出售公司的经营性资产，同时发行股份购买青海春天药用资源科技利用有限公司（下称青海春天）的股...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334241.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334241.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334241.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '戴小河'}],
#   'author': '戴小河',
#   'author_detail': {'name': '戴小河'},
#   'published': 'Fri, 01 Aug 2014 21:31:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=13, tm_min=31, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '中证解读：云天化“鸭梨山大” 责令子公司停产',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证解读：云天化“鸭梨山大” 责令子公司停产'},
#   'summary': '中证网讯 经历2013年的断臂求生后，云天化(600096)依然未能独善其身。在准备轻装上阵的漫漫长途中，云天化今责令其控股子<br><a href="http://stock.caijing.com.cn/2014-08-01/114334238.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 经历2013年的断臂求生后，云天化(600096)依然未能独善其身。在准备轻装上阵的漫漫长途中，云天化今责令其控股子<br><a href="http://stock.caijing.com.cn/2014-08-01/114334238.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334238.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334238.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '戴小河'}],
#   'author': '戴小河',
#   'author_detail': {'name': '戴小河'},
#   'published': 'Fri, 01 Aug 2014 20:58:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=12, tm_min=58, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '深交所：给予霞客环保董事兼时任总经理陈建忠公开谴责处分',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '深交所：给予霞客环保董事兼时任总经理陈建忠公开谴责处分'},
#   'summary': '据深交所公告，经查明，江苏霞客环保色纺股份有限公司（以下简称“公司”）董事兼时任总经理陈建忠存在违规行为，给予公开谴责的处分。<br><a href="http://stock.caijing.com.cn/2014-08-01/114334236.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '据深交所公告，经查明，江苏霞客环保色纺股份有限公司（以下简称“公司”）董事兼时任总经理陈建忠存在违规行为，给予公开谴责的处分。<br><a href="http://stock.caijing.com.cn/2014-08-01/114334236.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334236.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334236.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '张莉'}],
#   'author': '张莉',
#   'author_detail': {'name': '张莉'},
#   'published': 'Fri, 01 Aug 2014 20:25:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=12, tm_min=25, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '8月1日亚洲创业板行情数据一览',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '8月1日亚洲创业板行情数据一览'},
#   'summary': '.TRS_Editor P{}.TRS_Editor DIV{}.TRS_Editor TD{}.TRS_Editor TH{}.TRS_Editor SPAN{}.TRS_Editor FONT{}...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334222.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '.TRS_Editor P{}.TRS_Editor DIV{}.TRS_Editor TD{}.TRS_Editor TH{}.TRS_Editor SPAN{}.TRS_Editor FONT{}...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334222.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334222.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334222.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Fri, 01 Aug 2014 20:05:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=12, tm_min=5, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '8月1日创业板高活跃度个股一览',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '8月1日创业板高活跃度个股一览'},
#   'summary': '成交金额前十名的股票: 次序 股票代码 股票名称\u3000\u3000\u3000           成交金额        占板块(%)  1    300017<span class=articleLin<br><a href="http://stock.caijing.com.cn/2014-08-01/114334231.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '成交金额前十名的股票: 次序 股票代码 股票名称\u3000\u3000\u3000           成交金额        占板块(%)  1    300017<span class=articleLin<br><a href="http://stock.caijing.com.cn/2014-08-01/114334231.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334231.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334231.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Fri, 01 Aug 2014 20:04:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=12, tm_min=4, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '8月1日中小板高活跃度个股一览',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '8月1日中小板高活跃度个股一览'},
#   'summary': '成交金额前十名的股票: 次序 股票代码 股票名称\u3000\u3000\u3000      成交金额    占板块(%)  1    002204<a href<br><a href="http://stock.caijing.com.cn/2014-08-01/114334224.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '成交金额前十名的股票: 次序 股票代码 股票名称\u3000\u3000\u3000      成交金额    占板块(%)  1    002204<a href<br><a href="http://stock.caijing.com.cn/2014-08-01/114334224.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334224.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334224.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Fri, 01 Aug 2014 20:03:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=12, tm_min=3, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '航天晨光2014年上半年度净利同比11.82%',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '航天晨光2014年上半年度净利同比11.82%'},
#   'summary': '中证网讯航天晨光（600501）8月1日晚间公告表示，2014年上半年度归属于上市公司股东的净利润为28,043,380.77<br><a href="http://stock.caijing.com.cn/2014-08-01/114334226.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯航天晨光（600501）8月1日晚间公告表示，2014年上半年度归属于上市公司股东的净利润为28,043,380.77<br><a href="http://stock.caijing.com.cn/2014-08-01/114334226.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334226.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334226.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '申玉彬'}],
#   'author': '申玉彬',
#   'author_detail': {'name': '申玉彬'},
#   'published': 'Fri, 01 Aug 2014 20:03:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=12, tm_min=3, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '国通管业因拟召开董事会审议相关事项4日起停牌2天',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '国通管业因拟召开董事会审议相关事项4日起停牌2天'},
#   'summary': '中证网讯 国通管业（600444）8月1日晚间公告表示，公司拟于近期召开董事会审议相关事项，鉴于该事项存在重大不确定性，为保证公平信息披露，维护投资者利益，避免造成公司股价异常波动，经公司申请，公...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334227.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 国通管业（600444）8月1日晚间公告表示，公司拟于近期召开董事会审议相关事项，鉴于该事项存在重大不确定性，为保证公平信息披露，维护投资者利益，避免造成公司股价异常波动，经公司申请，公...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334227.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334227.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334227.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '申玉彬'}],
#   'author': '申玉彬',
#   'author_detail': {'name': '申玉彬'},
#   'published': 'Fri, 01 Aug 2014 20:02:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=12, tm_min=2, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '康芝药业澄清尼美舒利颗粒致死传闻不实',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '康芝药业澄清尼美舒利颗粒致死传闻不实'},
#   'summary': '中证网讯康芝药业（300086）8月1日晚间发布关于网络传闻的澄清公告，近日，在微博、微信朋友圈中出现有关某些医院 ICU 病<br><a href="http://stock.caijing.com.cn/2014-08-01/114334228.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯康芝药业（300086）8月1日晚间发布关于网络传闻的澄清公告，近日，在微博、微信朋友圈中出现有关某些医院 ICU 病<br><a href="http://stock.caijing.com.cn/2014-08-01/114334228.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334228.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334228.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '董宁宁'}],
#   'author': '董宁宁',
#   'author_detail': {'name': '董宁宁'},
#   'published': 'Fri, 01 Aug 2014 20:01:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=12, tm_min=1, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '中证解读：宝硕股份虚假陈述受罚 八年调查方水落石出',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证解读：宝硕股份虚假陈述受罚 八年调查方水落石出'},
#   'summary': '中证网讯 大股东占用巨额资金，上市公司助纣为虐长达6年，证监会立案调查8年终于水落石出。宝硕股份大股东占用资金案总算尘埃落定，业内专家向中国证券报记者指出，宝硕股份一案并非孤例，对于大股东占资顽疾...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334232.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 大股东占用巨额资金，上市公司助纣为虐长达6年，证监会立案调查8年终于水落石出。宝硕股份大股东占用资金案总算尘埃落定，业内专家向中国证券报记者指出，宝硕股份一案并非孤例，对于大股东占资顽疾...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334232.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334232.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334232.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '戴小河'}],
#   'author': '戴小河',
#   'author_detail': {'name': '戴小河'},
#   'published': 'Fri, 01 Aug 2014 19:58:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=11, tm_min=58, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '鲁北化工因研究论证重大事项4日起停牌',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '鲁北化工因研究论证重大事项4日起停牌'},
#   'summary': '中证网讯 鲁北化工（600727）8月1日晚间公告表示，因公司董事会拟于近日研究论证是否对正在推进的重大资产重组方案进行调整，目前正在与有关各方进行协商。鉴于该事项存在重大不确定性，为维护投资者利...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334229.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 鲁北化工（600727）8月1日晚间公告表示，因公司董事会拟于近日研究论证是否对正在推进的重大资产重组方案进行调整，目前正在与有关各方进行协商。鉴于该事项存在重大不确定性，为维护投资者利...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334229.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334229.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334229.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '申玉彬'}],
#   'author': '申玉彬',
#   'author_detail': {'name': '申玉彬'},
#   'published': 'Fri, 01 Aug 2014 19:55:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=11, tm_min=55, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '福星晓程拟非公开发行不超过1000万股 8月4日起复牌',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '福星晓程拟非公开发行不超过1000万股 8月4日起复牌'},
#   'summary': '中证网讯福星晓程（300139）8月1日晚间公告，公司拟非公开发行A股普通股的数量不超过1,000万股，股票的发行对象为公司控<br><a href="http://stock.caijing.com.cn/2014-08-01/114334230.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯福星晓程（300139）8月1日晚间公告，公司拟非公开发行A股普通股的数量不超过1,000万股，股票的发行对象为公司控<br><a href="http://stock.caijing.com.cn/2014-08-01/114334230.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334230.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334230.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '沈楠'}],
#   'author': '沈楠',
#   'author_detail': {'name': '沈楠'},
#   'published': 'Fri, 01 Aug 2014 19:54:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=11, tm_min=54, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '康缘药业因正筹划重大事项4日起停牌',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '康缘药业因正筹划重大事项4日起停牌'},
#   'summary': '中证网讯康缘药业（600557）8月1日晚间公告表示，因公司正在筹划重大事项，鉴于该事项存在重大不确定性，为保证公平信息披露，<br><a href="http://stock.caijing.com.cn/2014-08-01/114334223.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯康缘药业（600557）8月1日晚间公告表示，因公司正在筹划重大事项，鉴于该事项存在重大不确定性，为保证公平信息披露，<br><a href="http://stock.caijing.com.cn/2014-08-01/114334223.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334223.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334223.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '申玉彬'}],
#   'author': '申玉彬',
#   'author_detail': {'name': '申玉彬'},
#   'published': 'Fri, 01 Aug 2014 19:53:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=11, tm_min=53, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '华联矿业股东减持800万股',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '华联矿业股东减持800万股'},
#   'summary': '中证网讯 华联矿业（600882）8月1日晚间公告表示，公司于2014年8月1日收到股东淄博宏达矿业有限公司《关于减持山东华联矿业控股股份有限公司部分股份的告知函》，淄博宏达矿业有限公司于2014...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334233.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 华联矿业（600882）8月1日晚间公告表示，公司于2014年8月1日收到股东淄博宏达矿业有限公司《关于减持山东华联矿业控股股份有限公司部分股份的告知函》，淄博宏达矿业有限公司于2014...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334233.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334233.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334233.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '申玉彬'}],
#   'author': '申玉彬',
#   'author_detail': {'name': '申玉彬'},
#   'published': 'Fri, 01 Aug 2014 19:53:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=11, tm_min=53, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '沃华医药：心可舒片市场铺开助业绩反弹',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '沃华医药：心可舒片市场铺开助业绩反弹'},
#   'summary': '沃华医药1日晚间披露的中报显示，公司2014年上半年实现营业总收入14973.85万元，实现归属于上市公司股东的净利润445.5<br><a href="http://stock.caijing.com.cn/2014-08-01/114334225.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '沃华医药1日晚间披露的中报显示，公司2014年上半年实现营业总收入14973.85万元，实现归属于上市公司股东的净利润445.5<br><a href="http://stock.caijing.com.cn/2014-08-01/114334225.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334225.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334225.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '康书伟'}],
#   'author': '康书伟',
#   'author_detail': {'name': '康书伟'},
#   'published': 'Fri, 01 Aug 2014 19:51:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=11, tm_min=51, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '中证解读：方正证券并购民族证券获批文 或掀行业并购浪潮',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证解读：方正证券并购民族证券获批文 或掀行业并购浪潮'},
#   'summary': '中证网讯方正证券（601901）8月1日晚发布公告称，公司当日收到证监会《关于核准方正证券股份有限公司向北京政泉控股有限公司等<br><a href="http://stock.caijing.com.cn/2014-08-01/114334204.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯方正证券（601901）8月1日晚发布公告称，公司当日收到证监会《关于核准方正证券股份有限公司向北京政泉控股有限公司等<br><a href="http://stock.caijing.com.cn/2014-08-01/114334204.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334204.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334204.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '戴小河'}],
#   'author': '戴小河',
#   'author_detail': {'name': '戴小河'},
#   'published': 'Fri, 01 Aug 2014 19:30:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=11, tm_min=30, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '中证解读：深康佳“独吞”旧改项目诉求遭仲裁驳回',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证解读：深康佳“独吞”旧改项目诉求遭仲裁驳回'},
#   'summary': '中证网讯 深康佳的土地纠纷终于有了初步定论。8月1日晚，深康佳（000016）公告称，7月31日该公司收到深圳国际仲裁院的裁决书（华南国仲深裁 【2014】D97 号）。仲裁机构裁决驳回了康佳集团...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334205.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 深康佳的土地纠纷终于有了初步定论。8月1日晚，深康佳（000016）公告称，7月31日该公司收到深圳国际仲裁院的裁决书（华南国仲深裁 【2014】D97 号）。仲裁机构裁决驳回了康佳集团...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334205.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334205.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334205.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '刘兴龙'}],
#   'author': '刘兴龙',
#   'author_detail': {'name': '刘兴龙'},
#   'published': 'Fri, 01 Aug 2014 19:23:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=11, tm_min=23, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '中证解读：友阿股份设立云商子公司加速020平台建设',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证解读：友阿股份设立云商子公司加速020平台建设'},
#   'summary': '中证网讯 8月1日晚，友阿股份（002277）公告称，因发展规划及经营的需要，该公司拟以自有资金与深圳市融网汇智科技有限公司共<br><a href="http://stock.caijing.com.cn/2014-08-01/114334206.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 8月1日晚，友阿股份（002277）公告称，因发展规划及经营的需要，该公司拟以自有资金与深圳市融网汇智科技有限公司共<br><a href="http://stock.caijing.com.cn/2014-08-01/114334206.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334206.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334206.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '刘兴龙'}],
#   'author': '刘兴龙',
#   'author_detail': {'name': '刘兴龙'},
#   'published': 'Fri, 01 Aug 2014 19:22:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=11, tm_min=22, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '中证解读：华神集团利卡汀入选临床指南',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证解读：华神集团利卡汀入选临床指南'},
#   'summary': '中证网讯 8月1日晚，华神集团（000790）公告称，近日，公司收到公司控股子公司成都华神生物技术有限责任公司通报：公司 国家<br><a href="http://stock.caijing.com.cn/2014-08-01/114334202.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 8月1日晚，华神集团（000790）公告称，近日，公司收到公司控股子公司成都华神生物技术有限责任公司通报：公司 国家<br><a href="http://stock.caijing.com.cn/2014-08-01/114334202.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334202.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334202.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '刘兴龙'}],
#   'author': '刘兴龙',
#   'author_detail': {'name': '刘兴龙'},
#   'published': 'Fri, 01 Aug 2014 18:59:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=10, tm_min=59, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '中证解读：定增认购方生变 西王食品大股东包揽6亿融资',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证解读：定增认购方生变 西王食品大股东包揽6亿融资'},
#   'summary': '中证网讯 8月1日晚，西王食品（000639）发布公告称，由于证监会对非公开发行股票认购方的相关规定进行了调整，原预案已不符合<br><a href="http://stock.caijing.com.cn/2014-08-01/114334199.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 8月1日晚，西王食品（000639）发布公告称，由于证监会对非公开发行股票认购方的相关规定进行了调整，原预案已不符合<br><a href="http://stock.caijing.com.cn/2014-08-01/114334199.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334199.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334199.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '刘兴龙'}],
#   'author': '刘兴龙',
#   'author_detail': {'name': '刘兴龙'},
#   'published': 'Fri, 01 Aug 2014 18:41:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=10, tm_min=41, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '江苏霞客环保色纺股份有限公司陈建忠被深交所公开谴责处分',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '江苏霞客环保色纺股份有限公司陈建忠被深交所公开谴责处分'},
#   'summary': '中证网讯 据深交所公告，经查明，江苏霞客环保色纺股份有限公司（以<br><a href="http://stock.caijing.com.cn/2014-08-01/114334200.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 据深交所公告，经查明，江苏霞客环保色纺股份有限公司（以<br><a href="http://stock.caijing.com.cn/2014-08-01/114334200.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334200.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334200.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '张莉'}],
#   'author': '张莉',
#   'author_detail': {'name': '张莉'},
#   'published': 'Fri, 01 Aug 2014 18:32:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=10, tm_min=32, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '方正证券并购民族证券获批文 启动全面整合',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '方正证券并购民族证券获批文 启动全面整合'},
#   'summary': '中证网讯 8月1日，方正证券（601901）并购民族证券事项终于<br><a href="http://stock.caijing.com.cn/2014-08-01/114334201.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 8月1日，方正证券（601901）并购民族证券事项终于<br><a href="http://stock.caijing.com.cn/2014-08-01/114334201.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334201.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334201.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '李清理'}],
#   'author': '李清理',
# ...
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334192.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334192.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Fri, 01 Aug 2014 18:09:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=10, tm_min=9, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '冀东水泥全资及控股子公司累计收到增值税退税3620万元',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '冀东水泥全资及控股子公司累计收到增值税退税3620万元'},
#   'summary': '中证网讯冀东水泥（000401）8月1日晚间公告表示，根据财政部、国家税务总局联合下发的《关<br><a href="http://stock.caijing.com.cn/2014-08-01/114334193.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯冀东水泥（000401）8月1日晚间公告表示，根据财政部、国家税务总局联合下发的《关<br><a href="http://stock.caijing.com.cn/2014-08-01/114334193.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334193.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334193.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Fri, 01 Aug 2014 18:09:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=10, tm_min=9, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '中证解读：中兴商业遭大商系三度举牌',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证解读：中兴商业遭大商系三度举牌'},
#   'summary': '中证网讯 围绕在中兴商业（000715）身上的股权争夺正日趋激烈，在7月7日举牌之后的不足一个月里，大商投资管理有限公司又增持<br><a href="http://stock.caijing.com.cn/2014-08-01/114334197.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 围绕在中兴商业（000715）身上的股权争夺正日趋激烈，在7月7日举牌之后的不足一个月里，大商投资管理有限公司又增持<br><a href="http://stock.caijing.com.cn/2014-08-01/114334197.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334197.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334197.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{'name': '刘兴龙'}],
#   'author': '刘兴龙',
#   'author_detail': {'name': '刘兴龙'},
#   'published': 'Fri, 01 Aug 2014 18:09:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=10, tm_min=9, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '黑化股份股东昊华集团减持399万股',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '黑化股份股东昊华集团减持399万股'},
#   'summary': '中证网讯 黑化股份（600179）8月1日晚间公告表示，公司于2014年8月1日收到公司股东中国昊华化工集团股份有限公司（以下简称“昊华集团”）《股份减持告知函》。 昊华集团于2014年3月3日至20...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334194.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 黑化股份（600179）8月1日晚间公告表示，公司于2014年8月1日收到公司股东中国昊华化工集团股份有限公司（以下简称“昊华集团”）《股份减持告知函》。 昊华集团于2014年3月3日至20...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334194.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334194.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334194.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Fri, 01 Aug 2014 18:08:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=10, tm_min=8, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '新华制药收到补助金480万元',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '新华制药收到补助金480万元'},
#   'summary': '中证网讯新华制药（000756）8月1日晚间公告表示，根据淄博市经济和信息化委员<br><a href="http://stock.caijing.com.cn/2014-08-01/114334195.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯新华制药（000756）8月1日晚间公告表示，根据淄博市经济和信息化委员<br><a href="http://stock.caijing.com.cn/2014-08-01/114334195.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334195.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334195.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Fri, 01 Aug 2014 18:08:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=10, tm_min=8, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '海正药业非公开发行不超过1.4亿股新股事宜获核准',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '海正药业非公开发行不超过1.4亿股新股事宜获核准'},
#   'summary': '中证网讯海正药业（600267）8月1日晚间公告表示，2014年8月1日，公司收<br><a href="http://stock.caijing.com.cn/2014-08-01/114334196.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯海正药业（600267）8月1日晚间公告表示，2014年8月1日，公司收<br><a href="http://stock.caijing.com.cn/2014-08-01/114334196.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334196.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334196.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Fri, 01 Aug 2014 18:07:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=10, tm_min=7, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '云天化控股子公司昭通天合停产',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '云天化控股子公司昭通天合停产'},
#   'summary': '中证网讯云天化（600096）8月1日晚间公告表示，昭通天合有限责任公司（以下简<br><a href="http://stock.caijing.com.cn/2014-08-01/114334179.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯云天化（600096）8月1日晚间公告表示，昭通天合有限责任公司（以下简<br><a href="http://stock.caijing.com.cn/2014-08-01/114334179.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334179.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334179.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Fri, 01 Aug 2014 17:49:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=9, tm_min=49, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '上海佳豪子公司签6.5亿元动力干货船建造合同',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '上海佳豪子公司签6.5亿元动力干货船建造合同'},
#   'summary': '中证网讯上海佳豪（300008）8月1日晚间公告，公司近期收到全资子公司上海佳豪<br><a href="http://stock.caijing.com.cn/2014-08-01/114334180.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯上海佳豪（300008）8月1日晚间公告，公司近期收到全资子公司上海佳豪<br><a href="http://stock.caijing.com.cn/2014-08-01/114334180.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334180.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334180.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Fri, 01 Aug 2014 17:48:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=9, tm_min=48, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '天科股份2014年上半年度净利同比增15%',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '天科股份2014年上半年度净利同比增15%'},
#   'summary': '中证网讯天科股份（600378）8月1日晚间公告表示，2014年上半年度归属于上市公司股东的<br><a href="http://stock.caijing.com.cn/2014-08-01/114334181.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯天科股份（600378）8月1日晚间公告表示，2014年上半年度归属于上市公司股东的<br><a href="http://stock.caijing.com.cn/2014-08-01/114334181.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334181.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334181.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Fri, 01 Aug 2014 17:48:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=9, tm_min=48, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '雷曼光电上半年净利润1883万元 同比增长28%',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '雷曼光电上半年净利润1883万元 同比增长28%'},
#   'summary': '中证网讯雷曼光电（300162）8月1日晚间发布2014 年半年度报告，2014<br><a href="http://stock.caijing.com.cn/2014-08-01/114334182.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯雷曼光电（300162）8月1日晚间发布2014 年半年度报告，2014<br><a href="http://stock.caijing.com.cn/2014-08-01/114334182.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334182.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334182.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Fri, 01 Aug 2014 17:48:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=9, tm_min=48, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '翰宇药业取得一项发明专利证书 用于糖尿病血糖控制',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '翰宇药业取得一项发明专利证书 用于糖尿病血糖控制'},
#   'summary': '中证网讯翰宇药业（300199）8月1日晚间公告，公司于2014年8月1日取得了“一种稳定的<br><a href="http://stock.caijing.com.cn/2014-08-01/114334183.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯翰宇药业（300199）8月1日晚间公告，公司于2014年8月1日取得了“一种稳定的<br><a href="http://stock.caijing.com.cn/2014-08-01/114334183.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334183.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334183.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Fri, 01 Aug 2014 17:47:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=9, tm_min=47, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '尤洛卡1.4亿股限售股解禁 3911万股6日可上市流通',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '尤洛卡1.4亿股限售股解禁 3911万股6日可上市流通'},
#   'summary': '中证网讯尤洛卡（300099）8月1日晚间发布首次公开发行前已发行股份上市流通提示性公告，本<br><a href="http://stock.caijing.com.cn/2014-08-01/114334184.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯尤洛卡（300099）8月1日晚间发布首次公开发行前已发行股份上市流通提示性公告，本<br><a href="http://stock.caijing.com.cn/2014-08-01/114334184.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334184.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334184.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Fri, 01 Aug 2014 17:47:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=9, tm_min=47, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)},
#  {'title': '凯利泰棘突撑开器获得Ⅲ类医疗器械注册证',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '凯利泰棘突撑开器获得Ⅲ类医疗器械注册证'},
#   'summary': '中证网讯 凯利泰（300326）8月1日晚间公告，公司于近日获得国家食品药品监督管理局颁发的棘突撑开器（商品名：V-Crest）Ⅲ类《医疗器械注册证》（国食药监械（准）字2014第3461278号）。...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334185.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.caijing.com.cn/rss/stock_index.xml',
#    'value': '中证网讯 凯利泰（300326）8月1日晚间公告，公司于近日获得国家食品药品监督管理局颁发的棘突撑开器（商品名：V-Crest）Ⅲ类《医疗器械注册证》（国食药监械（准）字2014第3461278号）。...<br><a href="http://stock.caijing.com.cn/2014-08-01/114334185.html" target="_blank">[阅读全文]</a><br><a href="http://www.caijing.com.cn" target="_blank">[财经网]</a><br>'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://stock.caijing.com.cn/2014-08-01/114334185.html'}],
#   'link': 'http://stock.caijing.com.cn/2014-08-01/114334185.html',
#   'tags': [{'term': '证券频道首页', 'scheme': None, 'label': None}],
#   'authors': [{}],
#   'author': '',
#   'published': 'Fri, 01 Aug 2014 17:46:00 +0800',
#   'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=1, tm_hour=9, tm_min=46, tm_sec=0, tm_wday=4, tm_yday=213, tm_isdst=0)}]

# %%
len(ny['entries'])
# Out:
# 50

# %% [markdown]
# ## RSS源分类器及高频词去除函数

# %%
def calcMostFreq(vocabList, fullText):
    import operator
    freqDict = {}
    for token in vocabList:
        freqDict[token] = fullText.count(token)
    sortedFreq = sorted(freqDict.items(), key=operator.itemgetter(1), reverse=True)
    return sortedFreq[:30]

# %%
# 对中文语句进行词分，采用搜索引擎模式分词
def textParse(bigString):
    import jieba
    # 正则：匹配汉字
    regEx = re.compile('.*?([\u4E00-\u9FA5]+)')
    bigStringList = regEx.split(bigString)
    listOfTokens = jieba.lcut_for_search(''.join(bigStringList))
    # 去除标点和单字
    return [tok for tok in listOfTokens if len(tok) > 1]

# %%
# 创建一个包含在所有文档中出现的不重复词的列表
def createVocabList(dataSet):
    # 创建一个空集合，为了去重
    vocabSet = set([])
    for document in dataSet:
        # 创建两个集合的并集
        vocabSet = vocabSet | set(document)
    return list(vocabSet)

# %%
# 词袋模型
def bagOfWords2VecMN(vocabList, inputSet):
    returnVec = [0]*len(vocabList)
    for word in inputSet:
        if word in vocabList:
            returnVec[vocabList.index(word)] += 1
    return returnVec

# %%
# trainMatrix-文档矩阵，trainCategory-由每篇文档类别标签所构成的向量
def trainNB0(trainMatrix, trainCategory):
    numTrainDocs = len(trainMatrix)
    numWords = len(trainMatrix[0])
    # 求出有侮辱性词语的文档占比
    pAbusive = sum(trainCategory) / float(numTrainDocs)
    # 初始化概率，num为分子，denom为分母
    # 如果其中一个概率值为0， 那么最后的乘积也为0，为了降低这种影响，
    # 可以将所有词的出现数初始化为1， 并将分母初始化为2
    p0Num = np.ones(numWords)
    p1Num = np.ones(numWords)
    p0Denom = 2.0
    p1Denom = 2.0
    for i in range(numTrainDocs):
        # p1表示侮辱性词语，p0表示正常词语
        if trainCategory[i] == 1:
            # 向量相加
            # 侮辱性词语的词频数向量
            p1Num += trainMatrix[i]
            # 侮辱性词语的总词数
            p1Denom += sum(trainMatrix[i])
        else:
            p0Num += trainMatrix[i]
            p0Denom += sum(trainMatrix[i])
    # 对每个元素做除法，求出该词的概率即p(w|c)
    # 解决下溢出问题：利用ln(a*b)=ln(a)+ln(b)
    p1Vect = np.array([log(x) for x in p1Num/p1Denom])
    p0Vect = np.array([log(x) for x in p0Num/p0Denom])
    return p0Vect, p1Vect, pAbusive

# %%
def classifyNB(vec2Classify, p0Vec, p1Vec, pClass1):
    # 元素相乘，相当于p(w0|c1)p(w1|c1)...
    # 由于p(w)是一样的，所以在求p1的时候就不需要做除法运算了，计算p(c|w)
    p1 = sum(vec2Classify * p1Vec) + log(pClass1)
    p0 = sum(vec2Classify * p0Vec) + log(1.0 - pClass1)
    if p1 > p0:
        return 1
    else:
        return 0

# %%
def localWords(feed1, feed0):
    docList=[]; classList=[]; fullText=[]
    minLen = min(len(feed1['entries']), len(feed0['entries']))
    for i in range(minLen):
        wordList = textParse(feed1['entries'][i]['summary'])
        docList.append(wordList)
        fullText.extend(wordList)
        classList.append(1)
        wordList = textParse(feed0['entries'][i]['summary'])
        docList.append(wordList)
        fullText.extend(wordList)
        classList.append(0)
    vocabList = createVocabList(docList)
    top30Words = calcMostFreq(vocabList, fullText)
    for pairW in top30Words:
        if pairW[0] in vocabList:
            vocabList.remove(pairW[0])
    trainingSet = range(2*minLen); testSet = []
    for i in range(20):
        randIndex = int(random.uniform(0, len(trainingSet)))
        testSet.append(trainingSet[randIndex])
        del(list(trainingSet)[randIndex])
    trainMat = []; trainClasses = []
    for docIndex in trainingSet:
        trainMat.append(bagOfWords2VecMN(vocabList, docList[docIndex]))
        trainClasses.append(classList[docIndex])
    p0V, p1V, pSpam = trainNB0(np.array(trainMat), np.array(trainClasses))
    errorCount = 0
    for docIndex in testSet:
        wordVector = bagOfWords2VecMN(vocabList, docList[docIndex])
        if classifyNB(np.array(wordVector), p0V, p1V, pSpam) != classList[docIndex]:
            errorCount += 1
    print('the error rate is: ', float(errorCount) / len(testSet))
    return vocabList, p0V, p1V

# %%
# 宏观经济RSS源
economy = feedparser.parse('http://www.caijing.com.cn/rss/economy_index.xml')

# %%
# 证券RSS源
stock = feedparser.parse('http://www.caijing.com.cn/rss/stock_index.xml')

# %%
vocabList, pEconnmy, pStock = localWords(economy, stock)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\Hurf\AppData\Local\Temp\jieba.cache
# Loading model cost 2.721 seconds.
# Prefix dict has been built succesfully.
# the error rate is:  0.05

# %% [markdown]
# ## 分析数据：显示地域相关的用词

# %% [markdown]
# ### 最具表征性的词汇显示函数

# %%
def getTopWords(economy, stock):
    vocabList, p0V, p1V = localWords(economy, stock)
    topEconomy = []; topStock = []
    for i in range(len(p0V)):
        # 设置-5.0的概率阈值
        if p0V[i] > -5.0:
            topEconomy.append((vocabList[i], p0V[i]))
        if p1V[i] > -5.0:
            topStock.append((vocabList[i], p1V[i]))
    sortedStock = sorted(topStock, key = lambda pair: pair[1], reverse=True)
    print('Stock**Stock**Stock**Stock**Stock**Stock**Stock**Stock**Stock**Stock')
    for item in sortedStock:
        print(item[0])
    sortedEconomy = sorted(topEconomy, key = lambda pair: pair[1], reverse=True)
    print('Economy**Economy**Economy**Economy**Economy**Economy**Economy**Economy**Economy**Economy')
    for item in sortedEconomy:
        print(item[0])

# %%
getTopWords(economy, stock)
# Out:
# the error rate is:  0.0
# Stock**Stock**Stock**Stock**Stock**Stock**Stock**Stock**Stock**Stock
# 增长
# 全国
# 国人
# 会议
# 建设
# 中国人民银行
# Economy**Economy**Economy**Economy**Economy**Economy**Economy**Economy**Economy**Economy
# 上市
# 股东
# 集团
# 发行
# 金额
# 成交
# 上市公司
# 代码
# 证券
# 股票名称
# 事项
# 收到
# 名称
# 存在
# 属于
# 股票代码
# 归属
# 归属于
# 重大
# 次序
# 公开
# 控股
# 发布
