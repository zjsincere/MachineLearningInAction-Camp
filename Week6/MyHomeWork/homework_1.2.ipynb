# %% [markdown]
# # 手写识别问题：基于SVM的数字识别

# %% [markdown]
# 1. 收集数据：提供的文本文件。
# 2. 准备数据：基于二值图像构造向量。
# 3. 分析数据：对图像向量进行目测。
# 4. 训练算法：采用两种不同的核函数，并对径向基核函数采用不同的设置来运行SMO算法。
# 5. 测试算法：编写一个函数来测试不同的核函数并计算错误率。
# 6. 使用算法：一个图像识别的完整应用还需要一些图像处理的知识。

# %%
import numpy as np
import random

# %%
# 将图像转换为测试数据
def img2vector(fileName):
    returnVect = np.zeros((1, 1024))
    fr = open(fileName)
    # 一共32行数据
    for i in range(32):
        # 读取文件一行数据
        lineStr = fr.readline()
        for j in range(32):
            # 将该行数据存入returnVect向量中
            returnVect[0, 32*i+j] = int(lineStr[j])
    return returnVect

# %% [markdown]
# ## 基于SVM的手写数据识别

# %%
# 加载图片文件并创建训练集和特征标签
def loadImages(dirName):
    from os import listdir
    hwLabels = []
    trainingFileList = listdir(dirName)
    m = len(trainingFileList)
    trainingMat = np.zeros((m, 1024))
    for i in range(m):
        fileNameStr = trainingFileList[i]
        fileStr = fileNameStr.split('.')[0]
        classNumStr = int(fileStr.split('_')[0])
        # 碰到数字9，输入类别标签-1，否则输出+1
        if classNumStr == 9: hwLabels.append(-1)
        else: hwLabels.append(1)
        trainingMat[i, :] = img2vector('%s/%s' % (dirName, fileNameStr))
    return trainingMat, hwLabels

# %%
# kTup-第一个参数是描述所用核函数类型的一个字符串，其他2个参数则是核函数可能需要的可选参数
def kernelTrans(X, A, kTup):
    m, n = np.shape(X)
    K = np.mat(np.zeros((m, 1)))
    if kTup[0] == 'lin': K = X * A.T
    elif kTup[0] == 'rbf':
        for j in range(m):
            deltaRow = X[j,:] - A
            K[j] = deltaRow * deltaRow.T
        # 矩阵除法，对于矩阵元素展开计算
        K = np.exp(K / (-1 * kTup[1] ** 2))
    else: raise NameError('Houston We Have a Problem -- That Kernel is not recognized')
    return K

# %%
class optStruct:
    def __init__(self, dataMatIn, classLabels, C, toler, kTup):
        self.X = dataMatIn
        self.labelMat = classLabels
        self.C = C
        self.tol = toler
        self.m = np.shape(dataMatIn)[0]
        self.alphas = np.mat(np.zeros((self.m, 1)))
        self.b = 0
        self.eCache = np.mat(np.zeros((self.m, 2)))
        self.K = np.mat(np.zeros((self.m, self.m)))
        for i in range(self.m):
            self.K[:, i] = kernelTrans(self.X, self.X[i, :], kTup)

# %%
# 用于选择第二个alpha，内循环中的启发式方法
def selectJ(i, oS, Ei):
    maxK = -1; maxDeltaE = 0; Ej = 0
    # 首先将输入值Ei在缓存中设置成为有效的，表示已经计算好了
    oS.eCache[i] = [1, Ei]
    # 构建一个非零表
    validEcacheList = np.nonzero(oS.eCache[:,0].A)[0]
    if len(validEcacheList) > 1:
        for k in validEcacheList:
            if k == i : continue
            Ek = calcEk(oS, k)
            deltaE = abs(Ei - Ek)
            if deltaE > maxDeltaE:
                # 选择具有最大步长的j
                maxK = k; maxDeltaE = deltaE; Ej = Ek
        return maxK, Ej
    else:
        j = selectJrand(i, oS.m)
        Ej = calcEk(oS, j)
    return j, Ej

# 计算误差值，并存入缓存
def updateEk(oS, k):
    Ek = calcEk(oS, k)
    oS.eCache[k] = [1, Ek]

# %%
# i表示alpha的下标，m表示所有alpha的总数
# 随机取出一个不为i的下标
def selectJrand(i, m):
    j = i
    while (j == i):
        j = int(random.uniform(0, m))
    return j

# %%
# 用于调整大于H或者小于L的alpha值
def clipAlpha(aj, H, L):
    if aj > H:
        aj = H
    if L > aj:
        aj = L
    return aj

# %%
def innerL(i, oS):
    Ei = calcEk(oS, i)
    if ((oS.labelMat[i] * Ei < -oS.tol) and (oS.alphas[i] < oS.C)) or ((oS.labelMat[i] * Ei > oS.tol) and (oS.alphas[i] > 0)):
        j, Ej = selectJ(i, oS, Ei)
        alphaIold = oS.alphas[i].copy(); alphaJold = oS.alphas[j].copy()
        if oS.labelMat[i] != oS.labelMat[j]:
            L = max(0, oS.alphas[j] - oS.alphas[i])
            H = min(oS.C, oS.C + oS.alphas[j] - oS.alphas[i])
        else:
            L = max(0, oS.alphas[j] + oS.alphas[i] - oS.C)
            H = min(oS.C, oS.alphas[j] + oS.alphas[i])
        if L == H: print("L==H"); return 0
        eta = 2.0 * oS.K[i, j] - oS.K[i, i] - oS.K[j, j]
        if eta >= 0: print("eta >= 0"); return 0
        oS.alphas[j] -= oS.labelMat[j] * (Ei - Ej) / eta
        oS.alphas[j] = clipAlpha(oS.alphas[j], H, L)
        updateEk(oS, j)
        if abs(oS.alphas[j] - alphaJold) < 0.00001:
            print("j not moving enough"); return 0
        oS.alphas[i] += oS.labelMat[j] * oS.labelMat[i] * (alphaJold - oS.alphas[j])
        updateEk(oS, i)
        b1 = oS.b - Ei - oS.labelMat[i] * (oS.alphas[i] - alphaIold) * oS.K[i, i] - oS.labelMat[j] * (oS.alphas[j] - alphaJold) * oS.K[i, j]
        b2 = oS.b - Ej - oS.labelMat[i] * (oS.alphas[i] - alphaIold) * oS.K[i, j] - oS.labelMat[j] * (oS.alphas[j] - alphaJold) * oS.K[j, j]
        if 0 < oS.alphas[i] and oS.C > oS.alphas[i]:
            oS.b = b1
        elif 0 < oS.alphas[j] and oS.C > oS.alphas[j]:
            oS.b = b2
        else:
            oS.b = (b1 + b2) / 2.0
        return 1
    else:
        return 0

# %%
# 误差缓存
def calcEk(oS, k):
    fXk = float(np.multiply(oS.alphas, oS.labelMat).T * oS.K[:, k] + oS.b)
    Ek = fXk - float(oS.labelMat[k])
    return Ek

# %%
def smoP(dataMatIn, classLabels, C, toler, maxIter, kTup=('lin', 0)):
    oS = optStruct(np.mat(dataMatIn), np.mat(classLabels).transpose(), C, toler, kTup)
    iter = 0
    entireSet = True; alphaPairsChanged = 0
    while (iter < maxIter) and ((alphaPairsChanged > 0) or (entireSet)):
        alphaPairsChanged = 0
        if entireSet:
            # 遍历所有的值
            for i in range(oS.m):
                alphaPairsChanged += innerL(i, oS)
            print("fullSet, iter: %d i: %d, pairs changed %d" % (iter, i, alphaPairsChanged))
            iter += 1
        else:
            nonBoundIs = np.nonzero((oS.alphas.A > 0) * (oS.alphas.A < C))[0]
            # 遍历非边界值
            for i in nonBoundIs:
                alphaPairsChanged += innerL(i, oS)
                print("non-bound, iter: %d i: %d, pairs changed %d" % (iter, i, alphaPairsChanged))
                iter += 1
        if entireSet: entireSet = False
        elif alphaPairsChanged == 0: entireSet = True
        print("iteration number: %d" % iter)
    return oS.b, oS.alphas

# %%
def testDigits(kTup=('rbf', 10)):
    dataArr, labelArr = loadImages('trainingDigits')
    b, alphas = smoP(dataArr, labelArr, 200, 0.0001, 10000, kTup)
    dataMat = np.mat(dataArr); labelMat = np.mat(labelArr).transpose()
    svInd = np.nonzero(alphas.A > 0)[0]
    sVs = dataMat[svInd]
    labelSV = labelMat[svInd]
    print("there are %d Support Vectors" % np.shape(sVs)[0])
    m, n = np.shape(dataMat)
    errorCount = 0
    for i in range(m):
        kernelEval = kernelTrans(sVs, dataMat[i, :], kTup)
        predict = kernelEval.T * np.multiply(labelSV, alphas[svInd]) + b
        if np.sign(predict) != np.sign(labelArr[i]): errorCount += 1
    print("the training error rate is: %f" % (float(errorCount) / m))
    dataArr, labelArr = loadImages('testDigits')
    errorCount = 0
    dataMat = np.mat(dataArr); labelMat = np.mat(labelArr).transpose()
    m, n = np.shape(dataMat)
    for i in range(m):
        kernelEval = kernelTrans(sVs, dataMat[i, :], kTup)
        predict = kernelEval.T * np.multiply(labelSV, alphas[svInd]) + b
        if np.sign(predict) != np.sign(labelArr[i]): errorCount += 1
    print("the test error rate is: %f" % (float(errorCount) / m))

# %%
testDigits(('rbf', 20))
# Out:
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# fullSet, iter: 0 i: 401, pairs changed 36
# iteration number: 1
# non-bound, iter: 1 i: 3, pairs changed 1
# non-bound, iter: 2 i: 5, pairs changed 2
# non-bound, iter: 3 i: 7, pairs changed 3
# non-bound, iter: 4 i: 11, pairs changed 4
# non-bound, iter: 5 i: 12, pairs changed 5
# non-bound, iter: 6 i: 13, pairs changed 6
# non-bound, iter: 7 i: 14, pairs changed 7
# j not moving enough
# non-bound, iter: 8 i: 18, pairs changed 7
# j not moving enough
# non-bound, iter: 9 i: 20, pairs changed 7
# non-bound, iter: 10 i: 21, pairs changed 8
# j not moving enough
# non-bound, iter: 11 i: 105, pairs changed 8
# non-bound, iter: 12 i: 125, pairs changed 9
# non-bound, iter: 13 i: 127, pairs changed 10
# non-bound, iter: 14 i: 129, pairs changed 11
# j not moving enough
# non-bound, iter: 15 i: 130, pairs changed 11
# j not moving enough
# non-bound, iter: 16 i: 162, pairs changed 11
# j not moving enough
# non-bound, iter: 17 i: 189, pairs changed 11
# non-bound, iter: 18 i: 198, pairs changed 12
# non-bound, iter: 19 i: 199, pairs changed 13
# non-bound, iter: 20 i: 200, pairs changed 14
# non-bound, iter: 21 i: 201, pairs changed 15
# non-bound, iter: 22 i: 203, pairs changed 16
# non-bound, iter: 23 i: 204, pairs changed 17
# non-bound, iter: 24 i: 205, pairs changed 18
# non-bound, iter: 25 i: 207, pairs changed 19
# j not moving enough
# non-bound, iter: 26 i: 208, pairs changed 19
# non-bound, iter: 27 i: 209, pairs changed 20
# non-bound, iter: 28 i: 210, pairs changed 21
# non-bound, iter: 29 i: 211, pairs changed 22
# non-bound, iter: 30 i: 215, pairs changed 23
# non-bound, iter: 31 i: 218, pairs changed 24
# non-bound, iter: 32 i: 222, pairs changed 25
# j not moving enough
# non-bound, iter: 33 i: 235, pairs changed 25
# non-bound, iter: 34 i: 236, pairs changed 26
# non-bound, iter: 35 i: 237, pairs changed 27
# iteration number: 36
# j not moving enough
# non-bound, iter: 36 i: 3, pairs changed 0
# j not moving enough
# non-bound, iter: 37 i: 5, pairs changed 0
# non-bound, iter: 38 i: 7, pairs changed 1
# non-bound, iter: 39 i: 11, pairs changed 2
# j not moving enough
# non-bound, iter: 40 i: 12, pairs changed 2
# j not moving enough
# non-bound, iter: 41 i: 13, pairs changed 2
# non-bound, iter: 42 i: 14, pairs changed 3
# j not moving enough
# non-bound, iter: 43 i: 18, pairs changed 3
# j not moving enough
# non-bound, iter: 44 i: 20, pairs changed 3
# j not moving enough
# non-bound, iter: 45 i: 21, pairs changed 3
# j not moving enough
# non-bound, iter: 46 i: 98, pairs changed 3
# j not moving enough
# non-bound, iter: 47 i: 105, pairs changed 3
# j not moving enough
# non-bound, iter: 48 i: 125, pairs changed 3
# non-bound, iter: 49 i: 127, pairs changed 4
# j not moving enough
# non-bound, iter: 50 i: 129, pairs changed 4
# j not moving enough
# non-bound, iter: 51 i: 130, pairs changed 4
# non-bound, iter: 52 i: 162, pairs changed 5
# j not moving enough
# non-bound, iter: 53 i: 189, pairs changed 5
# non-bound, iter: 54 i: 198, pairs changed 6
# j not moving enough
# non-bound, iter: 55 i: 199, pairs changed 6
# j not moving enough
# non-bound, iter: 56 i: 205, pairs changed 6
# non-bound, iter: 57 i: 207, pairs changed 7
# j not moving enough
# non-bound, iter: 58 i: 208, pairs changed 7
# j not moving enough
# non-bound, iter: 59 i: 209, pairs changed 7
# j not moving enough
# non-bound, iter: 60 i: 215, pairs changed 7
# j not moving enough
# non-bound, iter: 61 i: 235, pairs changed 7
# j not moving enough
# non-bound, iter: 62 i: 249, pairs changed 7
# j not moving enough
# non-bound, iter: 63 i: 254, pairs changed 7
# j not moving enough
# non-bound, iter: 64 i: 284, pairs changed 7
# j not moving enough
# non-bound, iter: 65 i: 287, pairs changed 7
# j not moving enough
# non-bound, iter: 66 i: 311, pairs changed 7
# j not moving enough
# non-bound, iter: 67 i: 317, pairs changed 7
# j not moving enough
# non-bound, iter: 68 i: 318, pairs changed 7
# non-bound, iter: 69 i: 319, pairs changed 7
# j not moving enough
# non-bound, iter: 70 i: 322, pairs changed 7
# j not moving enough
# non-bound, iter: 71 i: 323, pairs changed 7
# j not moving enough
# non-bound, iter: 72 i: 330, pairs changed 7
# j not moving enough
# non-bound, iter: 73 i: 332, pairs changed 7
# j not moving enough
# non-bound, iter: 74 i: 334, pairs changed 7
# j not moving enough
# non-bound, iter: 75 i: 337, pairs changed 7
# j not moving enough
# non-bound, iter: 76 i: 343, pairs changed 7
# j not moving enough
# non-bound, iter: 77 i: 349, pairs changed 7
# j not moving enough
# non-bound, iter: 78 i: 362, pairs changed 7
# j not moving enough
# non-bound, iter: 79 i: 370, pairs changed 7
# j not moving enough
# non-bound, iter: 80 i: 401, pairs changed 7
# iteration number: 81
# j not moving enough
# non-bound, iter: 81 i: 3, pairs changed 0
# j not moving enough
# non-bound, iter: 82 i: 5, pairs changed 0
# j not moving enough
# non-bound, iter: 83 i: 7, pairs changed 0
# j not moving enough
# non-bound, iter: 84 i: 11, pairs changed 0
# j not moving enough
# non-bound, iter: 85 i: 12, pairs changed 0
# j not moving enough
# non-bound, iter: 86 i: 13, pairs changed 0
# j not moving enough
# non-bound, iter: 87 i: 14, pairs changed 0
# j not moving enough
# non-bound, iter: 88 i: 18, pairs changed 0
# j not moving enough
# non-bound, iter: 89 i: 20, pairs changed 0
# j not moving enough
# non-bound, iter: 90 i: 21, pairs changed 0
# non-bound, iter: 91 i: 98, pairs changed 1
# j not moving enough
# non-bound, iter: 92 i: 105, pairs changed 1
# j not moving enough
# non-bound, iter: 93 i: 125, pairs changed 1
# j not moving enough
# non-bound, iter: 94 i: 127, pairs changed 1
# j not moving enough
# non-bound, iter: 95 i: 129, pairs changed 1
# j not moving enough
# non-bound, iter: 96 i: 130, pairs changed 1
# j not moving enough
# non-bound, iter: 97 i: 162, pairs changed 1
# j not moving enough
# non-bound, iter: 98 i: 189, pairs changed 1
# j not moving enough
# non-bound, iter: 99 i: 198, pairs changed 1
# j not moving enough
# non-bound, iter: 100 i: 199, pairs changed 1
# j not moving enough
# non-bound, iter: 101 i: 205, pairs changed 1
# j not moving enough
# non-bound, iter: 102 i: 207, pairs changed 1
# non-bound, iter: 103 i: 208, pairs changed 2
# j not moving enough
# non-bound, iter: 104 i: 209, pairs changed 2
# non-bound, iter: 105 i: 215, pairs changed 3
# j not moving enough
# non-bound, iter: 106 i: 235, pairs changed 3
# j not moving enough
# non-bound, iter: 107 i: 249, pairs changed 3
# j not moving enough
# non-bound, iter: 108 i: 254, pairs changed 3
# j not moving enough
# non-bound, iter: 109 i: 284, pairs changed 3
# j not moving enough
# non-bound, iter: 110 i: 287, pairs changed 3
# non-bound, iter: 111 i: 293, pairs changed 3
# j not moving enough
# non-bound, iter: 112 i: 297, pairs changed 3
# j not moving enough
# non-bound, iter: 113 i: 311, pairs changed 3
# j not moving enough
# non-bound, iter: 114 i: 317, pairs changed 3
# non-bound, iter: 115 i: 318, pairs changed 4
# j not moving enough
# non-bound, iter: 116 i: 319, pairs changed 4
# j not moving enough
# non-bound, iter: 117 i: 322, pairs changed 4
# j not moving enough
# non-bound, iter: 118 i: 323, pairs changed 4
# j not moving enough
# non-bound, iter: 119 i: 329, pairs changed 4
# j not moving enough
# non-bound, iter: 120 i: 330, pairs changed 4
# j not moving enough
# non-bound, iter: 121 i: 332, pairs changed 4
# j not moving enough
# non-bound, iter: 122 i: 334, pairs changed 4
# j not moving enough
# non-bound, iter: 123 i: 337, pairs changed 4
# j not moving enough
# non-bound, iter: 124 i: 343, pairs changed 4
# j not moving enough
# non-bound, iter: 125 i: 349, pairs changed 4
# j not moving enough
# non-bound, iter: 126 i: 362, pairs changed 4
# j not moving enough
# non-bound, iter: 127 i: 370, pairs changed 4
# j not moving enough
# non-bound, iter: 128 i: 383, pairs changed 4
# j not moving enough
# non-bound, iter: 129 i: 401, pairs changed 4
# iteration number: 130
# j not moving enough
# non-bound, iter: 130 i: 3, pairs changed 0
# j not moving enough
# non-bound, iter: 131 i: 5, pairs changed 0
# j not moving enough
# non-bound, iter: 132 i: 7, pairs changed 0
# j not moving enough
# non-bound, iter: 133 i: 11, pairs changed 0
# j not moving enough
# non-bound, iter: 134 i: 12, pairs changed 0
# j not moving enough
# non-bound, iter: 135 i: 13, pairs changed 0
# j not moving enough
# non-bound, iter: 136 i: 14, pairs changed 0
# j not moving enough
# non-bound, iter: 137 i: 18, pairs changed 0
# j not moving enough
# non-bound, iter: 138 i: 20, pairs changed 0
# j not moving enough
# non-bound, iter: 139 i: 21, pairs changed 0
# j not moving enough
# non-bound, iter: 140 i: 98, pairs changed 0
# j not moving enough
# non-bound, iter: 141 i: 105, pairs changed 0
# j not moving enough
# non-bound, iter: 142 i: 125, pairs changed 0
# j not moving enough
# non-bound, iter: 143 i: 127, pairs changed 0
# j not moving enough
# non-bound, iter: 144 i: 129, pairs changed 0
# j not moving enough
# non-bound, iter: 145 i: 130, pairs changed 0
# j not moving enough
# non-bound, iter: 146 i: 162, pairs changed 0
# j not moving enough
# non-bound, iter: 147 i: 189, pairs changed 0
# j not moving enough
# non-bound, iter: 148 i: 198, pairs changed 0
# j not moving enough
# non-bound, iter: 149 i: 199, pairs changed 0
# j not moving enough
# non-bound, iter: 150 i: 205, pairs changed 0
# j not moving enough
# non-bound, iter: 151 i: 207, pairs changed 0
# j not moving enough
# non-bound, iter: 152 i: 208, pairs changed 0
# j not moving enough
# non-bound, iter: 153 i: 209, pairs changed 0
# j not moving enough
# non-bound, iter: 154 i: 215, pairs changed 0
# j not moving enough
# non-bound, iter: 155 i: 235, pairs changed 0
# j not moving enough
# non-bound, iter: 156 i: 249, pairs changed 0
# j not moving enough
# non-bound, iter: 157 i: 254, pairs changed 0
# j not moving enough
# non-bound, iter: 158 i: 284, pairs changed 0
# j not moving enough
# non-bound, iter: 159 i: 287, pairs changed 0
# j not moving enough
# non-bound, iter: 160 i: 293, pairs changed 0
# j not moving enough
# non-bound, iter: 161 i: 297, pairs changed 0
# j not moving enough
# non-bound, iter: 162 i: 311, pairs changed 0
# j not moving enough
# non-bound, iter: 163 i: 317, pairs changed 0
# non-bound, iter: 164 i: 318, pairs changed 0
# j not moving enough
# non-bound, iter: 165 i: 319, pairs changed 0
# j not moving enough
# non-bound, iter: 166 i: 322, pairs changed 0
# j not moving enough
# non-bound, iter: 167 i: 323, pairs changed 0
# j not moving enough
# non-bound, iter: 168 i: 329, pairs changed 0
# j not moving enough
# non-bound, iter: 169 i: 330, pairs changed 0
# j not moving enough
# non-bound, iter: 170 i: 332, pairs changed 0
# j not moving enough
# non-bound, iter: 171 i: 334, pairs changed 0
# j not moving enough
# non-bound, iter: 172 i: 337, pairs changed 0
# j not moving enough
# non-bound, iter: 173 i: 343, pairs changed 0
# j not moving enough
# non-bound, iter: 174 i: 349, pairs changed 0
# j not moving enough
# non-bound, iter: 175 i: 362, pairs changed 0
# j not moving enough
# non-bound, iter: 176 i: 370, pairs changed 0
# j not moving enough
# non-bound, iter: 177 i: 383, pairs changed 0
# non-bound, iter: 178 i: 389, pairs changed 0
# j not moving enough
# non-bound, iter: 179 i: 401, pairs changed 0
# iteration number: 180
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# L==H
# L==H
# j not moving enough
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# L==H
# L==H
# L==H
# L==H
# L==H
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# L==H
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# L==H
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# L==H
# j not moving enough
# L==H
# L==H
# j not moving enough
# L==H
# L==H
# j not moving enough
# L==H
# L==H
# L==H
# L==H
# j not moving enough
# fullSet, iter: 180 i: 401, pairs changed 16
# iteration number: 181
# non-bound, iter: 181 i: 3, pairs changed 0
# j not moving enough
# non-bound, iter: 182 i: 5, pairs changed 0
# j not moving enough
# non-bound, iter: 183 i: 7, pairs changed 0
# j not moving enough
# non-bound, iter: 184 i: 11, pairs changed 0
# j not moving enough
# non-bound, iter: 185 i: 12, pairs changed 0
# j not moving enough
# non-bound, iter: 186 i: 13, pairs changed 0
# j not moving enough
# non-bound, iter: 187 i: 14, pairs changed 0
# j not moving enough
# non-bound, iter: 188 i: 15, pairs changed 0
# j not moving enough
# non-bound, iter: 189 i: 18, pairs changed 0
# j not moving enough
# non-bound, iter: 190 i: 21, pairs changed 0
# j not moving enough
# non-bound, iter: 191 i: 44, pairs changed 0
# j not moving enough
# non-bound, iter: 192 i: 49, pairs changed 0
# j not moving enough
# non-bound, iter: 193 i: 54, pairs changed 0
# j not moving enough
# non-bound, iter: 194 i: 63, pairs changed 0
# j not moving enough
# non-bound, iter: 195 i: 65, pairs changed 0
# j not moving enough
# non-bound, iter: 196 i: 72, pairs changed 0
# j not moving enough
# non-bound, iter: 197 i: 81, pairs changed 0
# j not moving enough
# non-bound, iter: 198 i: 83, pairs changed 0
# j not moving enough
# non-bound, iter: 199 i: 85, pairs changed 0
# j not moving enough
# non-bound, iter: 200 i: 87, pairs changed 0
# j not moving enough
# non-bound, iter: 201 i: 98, pairs changed 0
# j not moving enough
# non-bound, iter: 202 i: 105, pairs changed 0
# j not moving enough
# non-bound, iter: 203 i: 113, pairs changed 0
# j not moving enough
# non-bound, iter: 204 i: 115, pairs changed 0
# j not moving enough
# non-bound, iter: 205 i: 117, pairs changed 0
# non-bound, iter: 206 i: 119, pairs changed 0
# j not moving enough
# non-bound, iter: 207 i: 125, pairs changed 0
# j not moving enough
# non-bound, iter: 208 i: 127, pairs changed 0
# j not moving enough
# non-bound, iter: 209 i: 129, pairs changed 0
# j not moving enough
# non-bound, iter: 210 i: 130, pairs changed 0
# j not moving enough
# non-bound, iter: 211 i: 162, pairs changed 0
# j not moving enough
# non-bound, iter: 212 i: 189, pairs changed 0
# j not moving enough
# non-bound, iter: 213 i: 198, pairs changed 0
# j not moving enough
# non-bound, iter: 214 i: 199, pairs changed 0
# j not moving enough
# non-bound, iter: 215 i: 205, pairs changed 0
# j not moving enough
# non-bound, iter: 216 i: 207, pairs changed 0
# j not moving enough
# non-bound, iter: 217 i: 208, pairs changed 0
# j not moving enough
# non-bound, iter: 218 i: 209, pairs changed 0
# j not moving enough
# non-bound, iter: 219 i: 215, pairs changed 0
# j not moving enough
# non-bound, iter: 220 i: 235, pairs changed 0
# j not moving enough
# non-bound, iter: 221 i: 249, pairs changed 0
# j not moving enough
# non-bound, iter: 222 i: 254, pairs changed 0
# j not moving enough
# non-bound, iter: 223 i: 284, pairs changed 0
# j not moving enough
# non-bound, iter: 224 i: 287, pairs changed 0
# j not moving enough
# non-bound, iter: 225 i: 290, pairs changed 0
# j not moving enough
# non-bound, iter: 226 i: 293, pairs changed 0
# j not moving enough
# non-bound, iter: 227 i: 297, pairs changed 0
# j not moving enough
# non-bound, iter: 228 i: 306, pairs changed 0
# j not moving enough
# non-bound, iter: 229 i: 311, pairs changed 0
# j not moving enough
# non-bound, iter: 230 i: 317, pairs changed 0
# j not moving enough
# non-bound, iter: 231 i: 318, pairs changed 0
# j not moving enough
# non-bound, iter: 232 i: 319, pairs changed 0
# j not moving enough
# non-bound, iter: 233 i: 322, pairs changed 0
# j not moving enough
# non-bound, iter: 234 i: 323, pairs changed 0
# j not moving enough
# non-bound, iter: 235 i: 325, pairs changed 0
# j not moving enough
# non-bound, iter: 236 i: 329, pairs changed 0
# j not moving enough
# non-bound, iter: 237 i: 330, pairs changed 0
# j not moving enough
# non-bound, iter: 238 i: 332, pairs changed 0
# j not moving enough
# non-bound, iter: 239 i: 334, pairs changed 0
# j not moving enough
# non-bound, iter: 240 i: 337, pairs changed 0
# j not moving enough
# non-bound, iter: 241 i: 343, pairs changed 0
# j not moving enough
# non-bound, iter: 242 i: 349, pairs changed 0
# j not moving enough
# non-bound, iter: 243 i: 362, pairs changed 0
# j not moving enough
# non-bound, iter: 244 i: 370, pairs changed 0
# j not moving enough
# non-bound, iter: 245 i: 383, pairs changed 0
# j not moving enough
# non-bound, iter: 246 i: 389, pairs changed 0
# j not moving enough
# non-bound, iter: 247 i: 401, pairs changed 0
# iteration number: 248
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# L==H
# L==H
# j not moving enough
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# L==H
# L==H
# L==H
# L==H
# L==H
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# L==H
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# L==H
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# L==H
# j not moving enough
# L==H
# L==H
# j not moving enough
# L==H
# L==H
# j not moving enough
# L==H
# L==H
# L==H
# L==H
# j not moving enough
# fullSet, iter: 248 i: 401, pairs changed 0
# iteration number: 249
# there are 67 Support Vectors
# the training error rate is: 0.000000
# the test error rate is: 0.010753
